# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.tsa.api import VAR, DynamicVAR
# data = pd.read_pickle("maha_pr_masked")
# model = VAR(data)

# %%
# !pip install -q rasterio

# %%
import xarray as xr
import os
from netCDF4 import Dataset 
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# get_ipython().run_line_magic('matplotlib', 'inline')
#plt.rcParams['figure.figsize'] = [50, 50]
from networkx import spring_layout
# import mplleaflet
# as get_ipython().run_line_magic('matplotlib', 'inline')
plt.rcParams['figure.figsize'] = [10, 10]
import statsmodels.api as sm
# import cdo
import pandas as pd
import salem
import networkx as nx

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)

# %%
from google.colab import files
uploaded = files.upload()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a95d7c51-5dbe-4e07-ac31-fcd5da89d083" name="files[]" multiple disabled />
#      <output id="result-a95d7c51-5dbe-4e07-ac31-fcd5da89d083">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving INDIA.shp to INDIA.shp
# Saving INDIA.shx to INDIA.shx
# Saving INDIA.sbx to INDIA.sbx
# Saving INDIA.sbn to INDIA.sbn
# Saving INDIA.prj to INDIA.prj
# Saving INDIA.dbf to INDIA.dbf

# %%
shape=salem.read_shapefile("rajasthan_administrative.shp")
daa = salem.open_xr_dataset("india_pre (1).nc")
das=daa.salem.subset(shape = shape,margin = 2)

# %%
daa=das.salem.roi(shape=shape)

# %%
daa.pr.mean(dim='time').plot()
# Out:
# /usr/local/lib/python3.6/dist-packages/xarray/core/nanops.py:161: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)

# %%
lati=daa["lat"].values
loni=daa["lon"].values

# %%
c=0
array=[]
G=nx.Graph()
for i in range(len(lati)):
    for j in range(len(loni)):
        if(daa.isel(lat=i,lon=j).pr.values[0]>0):
#             print(daa.isel(lat=i,lon=j).tas.values[0])
            c+=1
            G.add_node((loni[j],lati[i]),pos=(loni[j],lati[i]))
            array.append((loni[j],lati[i]))

# %%
G.nodes
# Out:
# NodeView(((77.34375, 9.104988856048523), (77.34375, 10.505756145243598), (78.75, 10.505756145243598), (75.9375, 11.906523334953757), (77.34375, 11.906523334953757), (78.75, 11.906523334953757), (75.9375, 13.307290410446194), (77.34375, 13.307290410446194), (78.75, 13.307290410446194), (80.15625, 13.307290410446194), (74.53125, 14.708057356404804), (75.9375, 14.708057356404804), (77.34375, 14.708057356404804), (78.75, 14.708057356404804), (74.53125, 16.108824156841283), (75.9375, 16.108824156841283), (77.34375, 16.108824156841283), (78.75, 16.108824156841283), (80.15625, 16.108824156841283), (74.53125, 17.509590794998555), (75.9375, 17.509590794998555), (77.34375, 17.509590794998555), (78.75, 17.509590794998555), (80.15625, 17.509590794998555), (81.5625, 17.509590794998555), (82.96875, 17.509590794998555), (73.125, 18.91035725324536), (74.53125, 18.91035725324536), (75.9375, 18.91035725324536), (77.34375, 18.91035725324536), (78.75, 18.91035725324536), (80.15625, 18.91035725324536), (81.5625, 18.91035725324536), (82.96875, 18.91035725324536), (84.375, 18.91035725324536), (73.125, 20.311123512960364), (74.53125, 20.311123512960364), (75.9375, 20.311123512960364), (77.34375, 20.311123512960364), (78.75, 20.311123512960364), (80.15625, 20.311123512960364), (81.5625, 20.311123512960364), (82.96875, 20.311123512960364), (84.375, 20.311123512960364), (85.78125, 20.311123512960364), (70.3125, 21.711889554404237), (71.71875, 21.711889554404237), (73.125, 21.711889554404237), (74.53125, 21.711889554404237), (75.9375, 21.711889554404237), (77.34375, 21.711889554404237), (78.75, 21.711889554404237), (80.15625, 21.711889554404237), (81.5625, 21.711889554404237), (82.96875, 21.711889554404237), (84.375, 21.711889554404237), (85.78125, 21.711889554404237), (87.1875, 21.711889554404237), (68.90625, 23.112655356577648), (70.3125, 23.112655356577648), (71.71875, 23.112655356577648), (73.125, 23.112655356577648), (74.53125, 23.112655356577648), (75.9375, 23.112655356577648), (77.34375, 23.112655356577648), (78.75, 23.112655356577648), (80.15625, 23.112655356577648), (81.5625, 23.112655356577648), (82.96875, 23.112655356577648), (84.375, 23.112655356577648), (85.78125, 23.112655356577648), (87.1875, 23.112655356577648), (88.59375, 23.112655356577648), (91.40625, 23.112655356577648), (92.8125, 23.112655356577648), (71.71875, 24.513420897062915), (73.125, 24.513420897062915), (74.53125, 24.513420897062915), (75.9375, 24.513420897062915), (77.34375, 24.513420897062915), (78.75, 24.513420897062915), (80.15625, 24.513420897062915), (81.5625, 24.513420897062915), (82.96875, 24.513420897062915), (84.375, 24.513420897062915), (85.78125, 24.513420897062915), (87.1875, 24.513420897062915), (92.8125, 24.513420897062915), (94.21875, 24.513420897062915), (70.3125, 25.914186151846668), (71.71875, 25.914186151846668), (73.125, 25.914186151846668), (74.53125, 25.914186151846668), (75.9375, 25.914186151846668), (77.34375, 25.914186151846668), (78.75, 25.914186151846668), (80.15625, 25.914186151846668), (81.5625, 25.914186151846668), (82.96875, 25.914186151846668), (84.375, 25.914186151846668), (85.78125, 25.914186151846668), (87.1875, 25.914186151846668), (90.0, 25.914186151846668), (91.40625, 25.914186151846668), (92.8125, 25.914186151846668), (94.21875, 25.914186151846668), (70.3125, 27.314951095120396), (71.71875, 27.314951095120396), (73.125, 27.314951095120396), (74.53125, 27.314951095120396), (75.9375, 27.314951095120396), (77.34375, 27.314951095120396), (78.75, 27.314951095120396), (80.15625, 27.314951095120396), (81.5625, 27.314951095120396), (82.96875, 27.314951095120396), (84.375, 27.314951095120396), (88.59375, 27.314951095120396), (92.8125, 27.314951095120396), (94.21875, 27.314951095120396), (95.625, 27.314951095120396), (73.125, 28.715715699055192), (74.53125, 28.715715699055192), (75.9375, 28.715715699055192), (77.34375, 28.715715699055192), (78.75, 28.715715699055192), (80.15625, 28.715715699055192), (94.21875, 28.715715699055192), (95.625, 28.715 ...

# %%
nx.draw_networkx_nodes(G, nx.get_node_attributes(G, 'pos'),alpha = 0.8,with_labels=True,node_shape = "o",figsize=(1000, 100),dpi=80,node_size=100)

# %%
df=pd.DataFrame()
for i in range(len(lati)):
    for j in range(len(loni)):
        if(daa.isel(lat=i,lon=j).pr.values[0]>0):
#             print(daa.isel(lat=i,lon=j).pr.values[0])
            arr=daa.isel(lat=i,lon=j).pr.values
            df[str(loni[j])+","+str(lati[i])]=arr[:3650]

# %%
daa.close()

# %%
df
# Out:
#       73.125,23.112655356577648  ...  75.9375,30.116479933546326
# 0                  3.020558e-05  ...                2.077761e-04
# 1                  7.472106e-06  ...                5.241911e-06
# 2                  1.357090e-05  ...                4.994174e-16
# 3                  3.652020e-06  ...                3.471227e-06
# 4                  2.225646e-06  ...                4.696525e-05
# 5                  9.435410e-07  ...                1.260932e-04
# 6                  1.314023e-05  ...                1.323368e-04
# 7                  2.239214e-06  ...                2.129327e-05
# 8                  3.808467e-07  ...                5.769827e-05
# 9                  2.997129e-08  ...                3.716440e-06
# 10                 4.267203e-06  ...                1.584961e-06
# 11                 2.578007e-05  ...                7.165621e-06
# 12                 5.940450e-05  ...                3.489049e-05
# 13                 1.481294e-05  ...                9.883277e-05
# 14                 1.832004e-05  ...                4.743125e-04
# 15                 1.000670e-06  ...                3.110115e-04
# 16                 1.019424e-16  ...                1.019424e-16
# 17                 3.045625e-14  ...                3.045625e-14
# 18                 8.518143e-19  ...                8.518143e-19
# 19                 9.892918e-18  ...                9.892918e-18
# 20                 1.398847e-22  ...                1.398847e-22
# 21                 2.842902e-17  ...                2.842902e-17
# 22                 1.316365e-15  ...                1.316365e-15
# 23                 1.679723e-15  ...                1.679723e-15
# 24                 1.008532e-15  ...                8.265940e-08
# 25                 7.175312e-19  ...                7.175312e-19
# 26                 6.987366e-18  ...                5.024830e-07
# 27                 6.375555e-17  ...                1.692219e-06
# 28                 1.084508e-15  ...                8.472127e-08
# 29                 2.840923e-18  ...                2.840923e-18
# ...                         ...  ...                         ...
# 3620               5.438712e-14  ...                5.438712e-14
# 3621               2.650695e-14  ...                2.650695e-14
# 3622               4.826051e-07  ...                4.021709e-07
# 3623               4.628778e-07  ...                2.314389e-07
# 3624               3.748957e-07  ...                1.639128e-05
# 3625               7.288317e-06  ...                5.659163e-06
# 3626               5.198071e-06  ...                1.222003e-06
# 3627               3.872922e-06  ...                4.641192e-05
# 3628               2.360983e-16  ...                1.624900e-04
# 3629               6.986901e-07  ...                1.537594e-04
# 3630               9.748949e-07  ...                2.511684e-05
# 3631               5.459951e-16  ...                1.879138e-08
# 3632               2.080235e-06  ...                5.372007e-14
# 3633               8.256210e-07  ...                2.106212e-05
# 3634               8.387839e-15  ...                3.037517e-06
# 3635               1.262117e-14  ...                4.046299e-05
# 3636               4.916208e-16  ...                4.759082e-06
# 3637               4.436098e-07  ...                4.742400e-05
# 3638               1.964586e-17  ...                5.022651e-06
# 3639               2.560884e-14  ...                2.560884e-14
# 3640               2.830709e-07  ...                3.774278e-07
# 3641               7.202522e-08  ...                9.603362e-08
# 3642               1.772551e-19  ...                1.772551e-19
# 3643               5.788892e-16  ...                5.788892e-16
# 3644               1.771369e-14  ...                1.771369e-14
# 3645               2.671119e-16  ...                2.671119e-16
# 3646               1.966108e-14  ...                1.966108e-14
# 3647               4.700946e-16  ...                4.700946e-16
# 3648               2.735204e-16  ...                2.735204e-16
# 3649               3.657894e-16  ...                3.657894e-16
#
# [3650 rows x 32 columns]

# %%
colum=df.columns.values
nodes=len(colum)
nodes
colum

# %%
model = VAR(df)
results = model.fit(maxlags=20, ic='aic')

# %%
neew=[]
for i in range(nodes):
  print(results.test_causality('73.125,23.112655356577648', colum[i], kind='f'))
# Out:
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 73.125,23.112655356577648 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 2.319, critical value: 1.571>, p-value: 0.001>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 74.53125,23.112655356577648 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 8.757, critical value: 1.571>, p-value: 0.000>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 75.9375,23.112655356577648 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 5.230, critical value: 1.571>, p-value: 0.000>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 70.3125,24.513420897062915 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 12.588, critical value: 1.571>, p-value: 0.000>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 71.71875,24.513420897062915 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 7.761, critical value: 1.571>, p-value: 0.000>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 73.125,24.513420897062915 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 2.236, critical value: 1.571>, p-value: 0.001>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 74.53125,24.513420897062915 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 2.981, critical value: 1.571>, p-value: 0.000>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 75.9375,24.513420897062915 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 4.342, critical value: 1.571>, p-value: 0.000>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 77.34375,24.513420897062915 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 4.927, critical value: 1.571>, p-value: 0.000>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 70.3125,25.914186151846668 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 3.010, critical value: 1.571>, p-value: 0.000>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 73.125,25.914186151846668 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 3.286, critical value: 1.571>, p-value: 0.000>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 74.53125,25.914186151846668 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 5.871, critical value: 1.571>, p-value: 0.000>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 75.9375,25.914186151846668 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 2.177, critical value: 1.571>, p-value: 0.002>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 77.34375,25.914186151846668 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 1.925, critical value: 1.571>, p-value: 0.008>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 78.75,25.914186151846668 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 3.774, critical value: 1.571>, p-value: 0.000>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 68.90625,27.314951095120396 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 10.203, critical value: 1.571>, p-value: 0.000>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 70.3125,27.314951095120396 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 6.591, critical value: 1.571>, p-value: 0.000>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 71.71875,27.314951095120396 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 3.184, critical value: 1.571>, p-value: 0.000>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 73.125,27.314951095120396 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 2.240, critical value: 1.571>, p-value: 0.001>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 74.53125,27.314951095120396 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 2.292, critical value: 1.571>, p-value: 0.001>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 75.9375,27.314951095120396 does not Granger-cause 73.125,23.112655356577648: fail to reject at 5% significance level. Test statistic: 1.300, critical value: 1.571>, p-value: 0.166>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 77.34375,27.314951095120396 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 1.690, critical value: 1.571>, p-value: 0.028>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 78.75,27.314951095120396 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 4.157, critical value: 1.571>, p-value: 0.000>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 70.3125,28.715715699055192 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 2.184, critical value: 1.571>, p-value: 0.002>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 71.71875,28.715715699055192 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 2.397, critical value: 1.571>, p-value: 0.000>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 73.125,28.715715699055192 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 2.874, critical value: 1.571>, p-value: 0.000>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 74.53125,28.715715699055192 does not Granger-cause 73.125,23.112655356577648: fail to reject at 5% significance level. Test statistic: 1.334, critical value: 1.571>, p-value: 0.145>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 75.9375,28.715715699055192 does not Granger-cause 73.125,23.112655356577648: fail to reject at 5% significance level. Test statistic: 1.185, critical value: 1.571>, p-value: 0.255>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 77.34375,28.715715699055192 does not Granger-cause 73.125,23.112655356577648: reject at 5% significance level. Test statistic: 1.734, critical value: 1.571>, p-value: 0.022>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 73.125,30.116479933546326 does not Granger-cause 73.125,23.112655356577648: fail to reject at 5% significance level. Test statistic: 1.120, critical value: 1.571>, p-value: 0.320>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 74.53125,30.116479933546326 does not Granger-cause 73.125,23.112655356577648: fail to reject at 5% significance level. Test statistic: 1.263, critical value: 1.571>, p-value: 0.192>
# <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults object. H_0: 75.9375,30.116479933546326 does not Granger-cause 73.125,23.112655356577648: fail to reject at 5% significance level. Test statistic: 0.973, critical value: 1.571>, p-value: 0.493>

# %%
neew
# Out:
# [<statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f17279bb828>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f17279bba58>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f17279bbd30>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f1727b0c080>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f1727b0c320>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f1727b0c5f8>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f1727b0c8d0>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f1727b0cba8>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f1727b0ce80>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f1727b091d0>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f1727b0cd30>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f1727b0c860>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f1727b0c550>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f1727b0c240>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f17279bbf98>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f17279bbc50>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f17279bb7f0>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f17279bb278>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f17279bf630>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f1727b09358>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f1727b090b8>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f1727b09518>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f1727b09748>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f1727b09940>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f1727b09c50>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f1727b09f60>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f1725d2c278>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f1725d2c518>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f1725d2c7f0>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f1725d2cac8>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f1725d2cda0>,
#  <statsmodels.tsa.vector_ar.hypothesis_test_results.CausalityTestResults at 0x7f1725d420f0>]

# %%
results.summary()

# %%
results.pvalues

# %%
imp=results.pvalues.iloc[449:]

# %%
imp

# %%
colum

# %%
len(imp.iloc[0])
# Out:
# 32

# %%
count=0
for i in range(nodes):
    for j in range(nodes):
        print(imp.iloc[i][j])
        if(imp.iloc[i][j]<0.05):
            
            G.add_edge((float(colum[i].split(",")[0]),float(colum[i].split(",")[1])),(float(colum[j].split(",")[0]),float(colum[j].split(",")[1])))
            count+=1

# %%
G.edges

# %%
 (float(colum[0].split(",")[0]),float(colum[0].split(",")[1]))

# %%
count

# %%
nx.draw_networkx(G ,nx.get_node_attributes(G, 'pos'),with_labels=False,edge_color="black", alpha=1,linewidths=2)
# plt.savefig("maha.png")

# %%
nx.density(G)
# Out:
# 0.3870967741935484
